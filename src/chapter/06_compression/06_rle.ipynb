# %% [markdown]
# # Run Length Encoding

# %% [markdown]
# Applications for the RLE.

# %%
import logging
logging.basicConfig(level=logging.WARN,format='%(levelname)s - %(message)s')
logging.getLogger("rle").setLevel(logging.DEBUG)
logging.getLogger("jupyter").setLevel(logging.DEBUG)
logger = logging.getLogger("jupyter")

# %%
# %matplotlib inline
import rle.rle

# %% [markdown]
# Encode / Decode a given string with RLE.

# %%
string = "kkkkkwwwwwaaaassdduggggggwppppp"
compressed_str = rle.rle.rle_compress(string)
decompressed_str = rle.rle.rle_decompress(compressed_str)

print(f"Original string    : {string}")
print(f"Compressed string  : {compressed_str}")
print(f"Decompressed string: {decompressed_str}")

# %% [markdown]
# Let's check if it works for >9 repetitions of a single char.

# %%
string = "zzwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwbbbbbbbddddddffqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqrrrttttttttttttttttttttttttt"
compressed_str = rle.rle.rle_compress(string)
decompressed_str = rle.rle.rle_decompress(compressed_str)

print(f"Original string    : {string}")
print(f"Compressed string  : {compressed_str}")
print(f"Decompressed string: {decompressed_str}")

# %% [markdown]
# Exercise from script:

# %%
string = "aaaabbcdddddddabcccbbbbb"
compressed_str = rle.rle.rle_compress(string)
decompressed_str = rle.rle.rle_decompress(compressed_str)

print(f"Original string    : {string}")
print(f"Compressed string  : {compressed_str}")
print(f"Decompressed string: {decompressed_str}")
