# %% [markdown]
# # Huffman Encoding

# %% [markdown]
# Examples for the Huffman encoding.

# %%
import logging
logging.basicConfig(level=logging.WARN,format='%(levelname)s - %(message)s')
logging.getLogger("huffman").setLevel(logging.DEBUG)
logging.getLogger("jupyter").setLevel(logging.DEBUG)
logger = logging.getLogger("jupyter")

# %%
# %matplotlib inline
import huffman.huffman

# %% [markdown]
# Encode / Decode using the Huffmann encoding.

# %%
string = "AABABCABCD"
encoded_str, heap_node = huffman.huffman.huffman_encode(string)
decoded_str = huffman.huffman.huffman_decode(encoded_str, heap_node)

print(f"Original string : {string}")
print(f"Encoded string  : {encoded_str}")
print(f"Decoded string  : {decoded_str}")
# Out:
# DEBUG - Char occurrence: [('D', 1), ('C', 2), ('B', 3), ('A', 4)]
# DEBUG - relativeFreqDict: {'A': 0.4, 'B': 0.3, 'C': 0.2, 'D': 0.1}
# DEBUG - heap: [D: 0.10, C: 0.20, B: 0.30, A: 0.40]
# DEBUG -   merging nodes: D: 0.10, C: 0.20 -> DC: 0.30
# DEBUG -   merging nodes: B: 0.30, DC: 0.30 -> BDC: 0.60
# DEBUG -   merging nodes: A: 0.40, BDC: 0.60 -> ABDC: 1.00
# DEBUG - merged_heapnode: ABDC: 1.00
# DEBUG - graph {
# 	ABDC [label="ABDC: 1.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	A [label="A: 0.40" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ABDC -- A [label=1]
# 	BDC [label="BDC: 0.60" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	B [label="B: 0.30" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	BDC -- B [label=1]
# 	DC [label="DC: 0.30" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	D [label="D: 0.10" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DC -- D [label=1]
# 	C [label="C: 0.20" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DC -- C [label=0]
# 	BDC -- DC [label=0]
# 	ABDC -- BDC [label=0]
# }
#
# DEBUG - codetable: {'A': '1', 'B': '01', 'D': '001', 'C': '000'}
# DEBUG - huffman_decode: 1 1 01 1 01 000 1 01 000 001
# DEBUG -   char: 1 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going left: A: 0.40
# DEBUG -     leaf reached: A
# DEBUG -   char: 1 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going left: A: 0.40
# DEBUG -     leaf reached: A
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 1 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going left: B: 0.30
# DEBUG -     leaf reached: B
# DEBUG -   char: 1 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going left: A: 0.40
# DEBUG -     leaf reached: A
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 1 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going left: B: 0.30
# DEBUG -     leaf reached: B
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 0 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going right: DC: 0.30
# DEBUG -   char: 0 | current node: DC: 0.30     -- left: D: 0.10 | right: C: 0.20
# DEBUG -     going right: C: 0.20
# DEBUG -     leaf reached: C
# DEBUG -   char: 1 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going left: A: 0.40
# DEBUG -     leaf reached: A
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 1 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going left: B: 0.30
# DEBUG -     leaf reached: B
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 0 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going right: DC: 0.30
# DEBUG -   char: 0 | current node: DC: 0.30     -- left: D: 0.10 | right: C: 0.20
# DEBUG -     going right: C: 0.20
# DEBUG -     leaf reached: C
# DEBUG -   char: 0 | current node: ABDC: 1.00     -- left: A: 0.40 | right: BDC: 0.60
# DEBUG -     going right: BDC: 0.60
# DEBUG -   char: 0 | current node: BDC: 0.60     -- left: B: 0.30 | right: DC: 0.30
# DEBUG -     going right: DC: 0.30
# DEBUG -   char: 1 | current node: DC: 0.30     -- left: D: 0.10 | right: C: 0.20
# DEBUG -     going left: D: 0.10
# DEBUG -     leaf reached: D
# Original string : AABABCABCD
# Encoded string  : 1 1 01 1 01 000 1 01 000 001
# Decoded string  : AABABCABCD

# %% [markdown]
# Let's use a more complicated example: Friedrich Schiller, Das Lied von der Glocke (1799).

# %%
import re

text = """
Fest gemauert in der Erden
Steht die Form, aus Lehm gebrannt.
Heute muss die Glocke werden
Frisch Gesellen, seid zur Hand.
Von der Stirne heiß
Rinnen muss der Schweiß,
Soll das Werk den Meister loben,
Doch der Segen kommt von oben.

Zum Werke, das wir ernst bereiten,
Geziemt sich wohl ein ernstes Wort;
Wenn gute Reden sie begleiten,
Dann fließt die Arbeit munter fort.
So lasst uns jetzt mit Fleiß betrachten,
Was durch die schwache Kraft entspringt,
Den schlechten Mann muss man verachten,
Der nie bedacht, was er vollbringt.
Das ist's ja, was den Menschen zieret,
Und dazu ward ihm der Verstand,
Dass er im innern Herzen spüret,
Was er erschafft mit seiner Hand.
""".replace("\n", " ")
text = re.sub('[^A-Za-z äüöÄÜÖß]', '', text)

encoded_str, heap_node = huffman.huffman.huffman_encode(text)
decoded_str = huffman.huffman.huffman_decode(encoded_str, heap_node)

print(f"Original string : ({len(text)} bytes) {text}")
print(f"Encoded string  : ({len( encoded_str.replace(' ', '') )//8 + 1} bytes) {encoded_str}")
print(f"Decoded string  : {decoded_str}")
# Out:
# DEBUG - Char occurrence: [('E', 1), ('L', 1), ('Z', 1), ('A', 1), ('K', 1), ('U', 1), ('ü', 1), ('V', 2), ('R', 2), ('j', 2), ('p', 2), ('G', 3), ('M', 3), ('v', 3), ('F', 4), ('H', 4), ('k', 4), ('ß', 4), ('f', 5), ('S', 6), ('z', 6), ('W', 6), ('D', 6), ('g', 7), ('w', 8), ('b', 9), ('u', 13), ('o', 14), ('l', 14), ('c', 15), ('m', 16), ('h', 19), ('d', 25), ('a', 27), ('i', 33), ('s', 39), ('t', 39), ('r', 42), ('n', 51), ('e', 89), (' ', 116)]
# DEBUG - relativeFreqDict: {' ': 0.17984496124031008, 'F': 0.006201550387596899, 'e': 0.13798449612403102, 's': 0.06046511627906977, 't': 0.06046511627906977, 'g': 0.010852713178294573, 'm': 0.024806201550387597, 'a': 0.04186046511627907, 'u': 0.020155038759689922, 'r': 0.06511627906976744, 'i': 0.05116279069767442, 'n': 0.07906976744186046, 'd': 0.03875968992248062, 'E': 0.0015503875968992248, 'S': 0.009302325581395349, 'h': 0.02945736434108527, 'o': 0.021705426356589147, 'L': 0.0015503875968992248, 'b': 0.013953488372093023, 'H': 0.006201550387596899, 'G': 0.004651162790697674, 'l': 0.021705426356589147, 'c': 0.023255813953488372, 'k': 0.006201550387596899, 'w': 0.012403100775193798, 'z': 0.009302325581395349, 'V': 0.0031007751937984496, 'ß': 0.006201550387596899, 'R': 0.0031007751937984496, 'W': 0.009302325581395349, 'M': 0.004651162790697674, 'D': 0.009302325581395349, 'v': 0.004651162790697674, 'Z': 0.0015503875968992248, 'f': 0.007751937984496124, 'A': 0.0015503875968992248, 'j': 0.0031007751937984496, 'K': 0.0015503875968992248, 'p': 0.0031007751937984496, 'U': 0.0015503875968992248, 'ü': 0.0015503875968992248}
# DEBUG - heap: [E: 0.00, L: 0.00, V: 0.00, Z: 0.00, U: 0.00, F: 0.01, R: 0.00, v: 0.00, A: 0.00, ü: 0.00, l: 0.02, w: 0.01, k: 0.01, ß: 0.01, M: 0.00, b: 0.01, f: 0.01, j: 0.00, K: 0.00, G: 0.00, i: 0.05, t: 0.06, c: 0.02, e: 0.14, d: 0.04, n: 0.08, z: 0.01, m: 0.02, S: 0.01, g: 0.01, W: 0.01,  : 0.18, h: 0.03, a: 0.04, D: 0.01, s: 0.06, u: 0.02, o: 0.02, p: 0.00, r: 0.07, H: 0.01]
# DEBUG -   merging nodes: E: 0.00, L: 0.00 -> EL: 0.00
# DEBUG -   merging nodes: U: 0.00, ü: 0.00 -> Uü: 0.00
# DEBUG -   merging nodes: Z: 0.00, A: 0.00 -> ZA: 0.00
# DEBUG -   merging nodes: K: 0.00, V: 0.00 -> KV: 0.00
# DEBUG -   merging nodes: R: 0.00, EL: 0.00 -> REL: 0.01
# DEBUG -   merging nodes: p: 0.00, Uü: 0.00 -> pUü: 0.01
# DEBUG -   merging nodes: ZA: 0.00, j: 0.00 -> ZAj: 0.01
# DEBUG -   merging nodes: M: 0.00, G: 0.00 -> MG: 0.01
# DEBUG -   merging nodes: KV: 0.00, v: 0.00 -> KVv: 0.01
# DEBUG -   merging nodes: ß: 0.01, F: 0.01 -> ßF: 0.01
# DEBUG -   merging nodes: k: 0.01, H: 0.01 -> kH: 0.01
# DEBUG -   merging nodes: REL: 0.01, pUü: 0.01 -> RELpUü: 0.01
# DEBUG -   merging nodes: ZAj: 0.01, f: 0.01 -> ZAjf: 0.01
# DEBUG -   merging nodes: W: 0.01, S: 0.01 -> WS: 0.02
# DEBUG -   merging nodes: z: 0.01, KVv: 0.01 -> zKVv: 0.02
# DEBUG -   merging nodes: D: 0.01, MG: 0.01 -> DMG: 0.02
# DEBUG -   merging nodes: g: 0.01, RELpUü: 0.01 -> gRELpUü: 0.02
# DEBUG -   merging nodes: w: 0.01, kH: 0.01 -> wkH: 0.02
# DEBUG -   merging nodes: ßF: 0.01, ZAjf: 0.01 -> ßFZAjf: 0.03
# DEBUG -   merging nodes: b: 0.01, WS: 0.02 -> bWS: 0.03
# DEBUG -   merging nodes: DMG: 0.02, zKVv: 0.02 -> DMGzKVv: 0.04
# DEBUG -   merging nodes: u: 0.02, l: 0.02 -> ul: 0.04
# DEBUG -   merging nodes: o: 0.02, gRELpUü: 0.02 -> ogRELpUü: 0.04
# DEBUG -   merging nodes: c: 0.02, m: 0.02 -> cm: 0.05
# DEBUG -   merging nodes: wkH: 0.02, ßFZAjf: 0.03 -> wkHßFZAjf: 0.05
# DEBUG -   merging nodes: h: 0.03, bWS: 0.03 -> hbWS: 0.06
# DEBUG -   merging nodes: DMGzKVv: 0.04, d: 0.04 -> DMGzKVvd: 0.08
# DEBUG -   merging nodes: ul: 0.04, a: 0.04 -> ula: 0.08
# DEBUG -   merging nodes: ogRELpUü: 0.04, cm: 0.05 -> ogRELpUücm: 0.09
# DEBUG -   merging nodes: i: 0.05, wkHßFZAjf: 0.05 -> iwkHßFZAjf: 0.10
# DEBUG -   merging nodes: s: 0.06, t: 0.06 -> st: 0.12
# DEBUG -   merging nodes: hbWS: 0.06, r: 0.07 -> hbWSr: 0.13
# DEBUG -   merging nodes: DMGzKVvd: 0.08, n: 0.08 -> DMGzKVvdn: 0.16
# DEBUG -   merging nodes: ula: 0.08, ogRELpUücm: 0.09 -> ulaogRELpUücm: 0.18
# DEBUG -   merging nodes: iwkHßFZAjf: 0.10, st: 0.12 -> iwkHßFZAjfst: 0.22
# DEBUG -   merging nodes: hbWSr: 0.13, e: 0.14 -> hbWSre: 0.27
# DEBUG -   merging nodes: DMGzKVvdn: 0.16, ulaogRELpUücm: 0.18 -> DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   merging nodes:  : 0.18, iwkHßFZAjfst: 0.22 ->  iwkHßFZAjfst: 0.40
# DEBUG -   merging nodes: hbWSre: 0.27, DMGzKVvdnulaogRELpUücm: 0.33 -> hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   merging nodes:  iwkHßFZAjfst: 0.40, hbWSreDMGzKVvdnulaogRELpUücm: 0.60 ->  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00
# DEBUG - merged_heapnode:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00
# DEBUG - graph {
# 	" iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm" [label=" iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	" iwkHßFZAjfst" [label=" iwkHßFZAjfst: 0.40" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	" " [label=" : 0.18" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	" iwkHßFZAjfst" -- " " [label=1]
# 	"iwkHßFZAjfst" [label="iwkHßFZAjfst: 0.22" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"iwkHßFZAjf" [label="iwkHßFZAjf: 0.10" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	i [label="i: 0.05" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"iwkHßFZAjf" -- i [label=1]
# 	"wkHßFZAjf" [label="wkHßFZAjf: 0.05" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	wkH [label="wkH: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	w [label="w: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	wkH -- w [label=1]
# 	kH [label="kH: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	k [label="k: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	kH -- k [label=1]
# 	H [label="H: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	kH -- H [label=0]
# 	wkH -- kH [label=0]
# 	"wkHßFZAjf" -- wkH [label=1]
# 	"ßFZAjf" [label="ßFZAjf: 0.03" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ßF" [label="ßF: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ß" [label="ß: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ßF" -- "ß" [label=1]
# 	F [label="F: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ßF" -- F [label=0]
# 	"ßFZAjf" -- "ßF" [label=1]
# 	ZAjf [label="ZAjf: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZAj [label="ZAj: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZA [label="ZA: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	Z [label="Z: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZA -- Z [label=1]
# 	A [label="A: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZA -- A [label=0]
# 	ZAj -- ZA [label=1]
# 	j [label="j: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZAj -- j [label=0]
# 	ZAjf -- ZAj [label=1]
# 	f [label="f: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ZAjf -- f [label=0]
# 	"ßFZAjf" -- ZAjf [label=0]
# 	"wkHßFZAjf" -- "ßFZAjf" [label=0]
# 	"iwkHßFZAjf" -- "wkHßFZAjf" [label=0]
# 	"iwkHßFZAjfst" -- "iwkHßFZAjf" [label=1]
# 	st [label="st: 0.12" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	s [label="s: 0.06" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	st -- s [label=1]
# 	t [label="t: 0.06" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	st -- t [label=0]
# 	"iwkHßFZAjfst" -- st [label=0]
# 	" iwkHßFZAjfst" -- "iwkHßFZAjfst" [label=0]
# 	" iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm" -- " iwkHßFZAjfst" [label=1]
# 	"hbWSreDMGzKVvdnulaogRELpUücm" [label="hbWSreDMGzKVvdnulaogRELpUücm: 0.60" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWSre [label="hbWSre: 0.27" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWSr [label="hbWSr: 0.13" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWS [label="hbWS: 0.06" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	h [label="h: 0.03" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWS -- h [label=1]
# 	bWS [label="bWS: 0.03" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	b [label="b: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	bWS -- b [label=1]
# 	WS [label="WS: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	W [label="W: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	WS -- W [label=1]
# 	S [label="S: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	WS -- S [label=0]
# 	bWS -- WS [label=0]
# 	hbWS -- bWS [label=0]
# 	hbWSr -- hbWS [label=1]
# 	r [label="r: 0.07" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWSr -- r [label=0]
# 	hbWSre -- hbWSr [label=1]
# 	e [label="e: 0.14" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	hbWSre -- e [label=0]
# 	"hbWSreDMGzKVvdnulaogRELpUücm" -- hbWSre [label=1]
# 	"DMGzKVvdnulaogRELpUücm" [label="DMGzKVvdnulaogRELpUücm: 0.33" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMGzKVvdn [label="DMGzKVvdn: 0.16" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMGzKVvd [label="DMGzKVvd: 0.08" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMGzKVv [label="DMGzKVv: 0.04" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMG [label="DMG: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	D [label="D: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMG -- D [label=1]
# 	MG [label="MG: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	M [label="M: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	MG -- M [label=1]
# 	G [label="G: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	MG -- G [label=0]
# 	DMG -- MG [label=0]
# 	DMGzKVv -- DMG [label=1]
# 	zKVv [label="zKVv: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	z [label="z: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	zKVv -- z [label=1]
# 	KVv [label="KVv: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	KV [label="KV: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	K [label="K: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	KV -- K [label=1]
# 	V [label="V: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	KV -- V [label=0]
# 	KVv -- KV [label=1]
# 	v [label="v: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	KVv -- v [label=0]
# 	zKVv -- KVv [label=0]
# 	DMGzKVv -- zKVv [label=0]
# 	DMGzKVvd -- DMGzKVv [label=1]
# 	d [label="d: 0.04" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMGzKVvd -- d [label=0]
# 	DMGzKVvdn -- DMGzKVvd [label=1]
# 	n [label="n: 0.08" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	DMGzKVvdn -- n [label=0]
# 	"DMGzKVvdnulaogRELpUücm" -- DMGzKVvdn [label=1]
# 	"ulaogRELpUücm" [label="ulaogRELpUücm: 0.18" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ula [label="ula: 0.08" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ul [label="ul: 0.04" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	u [label="u: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ul -- u [label=1]
# 	l [label="l: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ul -- l [label=0]
# 	ula -- ul [label=1]
# 	a [label="a: 0.04" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	ula -- a [label=0]
# 	"ulaogRELpUücm" -- ula [label=1]
# 	"ogRELpUücm" [label="ogRELpUücm: 0.09" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ogRELpUü" [label="ogRELpUü: 0.04" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	o [label="o: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"ogRELpUü" -- o [label=1]
# 	"gRELpUü" [label="gRELpUü: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	g [label="g: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"gRELpUü" -- g [label=1]
# 	"RELpUü" [label="RELpUü: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	REL [label="REL: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	R [label="R: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	REL -- R [label=1]
# 	EL [label="EL: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	E [label="E: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	EL -- E [label=1]
# 	L [label="L: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	EL -- L [label=0]
# 	REL -- EL [label=0]
# 	"RELpUü" -- REL [label=1]
# 	"pUü" [label="pUü: 0.01" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	p [label="p: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"pUü" -- p [label=1]
# 	"Uü" [label="Uü: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	U [label="U: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"Uü" -- U [label=1]
# 	"ü" [label="ü: 0.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	"Uü" -- "ü" [label=0]
# 	"pUü" -- "Uü" [label=0]
# 	"RELpUü" -- "pUü" [label=0]
# 	"gRELpUü" -- "RELpUü" [label=0]
# 	"ogRELpUü" -- "gRELpUü" [label=0]
# 	"ogRELpUücm" -- "ogRELpUü" [label=1]
# 	cm [label="cm: 0.05" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	c [label="c: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	cm -- c [label=1]
# 	m [label="m: 0.02" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	cm -- m [label=0]
# 	"ogRELpUücm" -- cm [label=0]
# 	"ulaogRELpUücm" -- "ogRELpUücm" [label=0]
# 	"DMGzKVvdnulaogRELpUücm" -- "ulaogRELpUücm" [label=0]
# 	"hbWSreDMGzKVvdnulaogRELpUücm" -- "DMGzKVvdnulaogRELpUücm" [label=0]
# 	" iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm" -- "hbWSreDMGzKVvdnulaogRELpUücm" [label=0]
# }
#
# DEBUG - codetable: {' ': '11', 'i': '1011', 'w': '101011', 'k': '1010101', 'H': '1010100', 'ß': '1010011', 'F': '1010010', 'Z': '101000111', 'A': '101000110', 'j': '10100010', 'f': '1010000', 's': '1001', 't': '1000', 'h': '01111', 'b': '011101', 'W': '0111001', 'S': '0111000', 'r': '0110', 'e': '010', 'D': '0011111', 'M': '00111101', 'G': '00111100', 'z': '0011101', 'K': '001110011', 'V': '001110010', 'v': '00111000', 'd': '00110', 'n': '0010', 'u': '000111', 'l': '000110', 'a': '00010', 'o': '000011', 'g': '0000101', 'R': '000010011', 'E': '0000100101', 'L': '0000100100', 'p': '000010001', 'U': '0000100001', 'ü': '0000100000', 'c': '000001', 'm': '000000'}
# DEBUG - huffman_decode: 11 1010010 010 1001 1000 11 0000101 010 000000 00010 000111 010 0110 1000 11 1011 0010 11 00110 010 0110 11 0000100101 0110 00110 010 0010 11 0111000 1000 010 01111 1000 11 00110 1011 010 11 1010010 000011 0110 000000 11 00010 000111 1001 11 0000100100 010 01111 000000 11 0000101 010 011101 0110 00010 0010 0010 1000 11 1010100 010 000111 1000 010 11 000000 000111 1001 1001 11 00110 1011 010 11 00111100 000110 000011 000001 1010101 010 11 101011 010 0110 00110 010 0010 11 1010010 0110 1011 1001 000001 01111 11 00111100 010 1001 010 000110 000110 010 0010 11 1001 010 1011 00110 11 0011101 000111 0110 11 1010100 00010 0010 00110 11 001110010 000011 0010 11 00110 010 0110 11 0111000 1000 1011 0110 0010 010 11 01111 010 1011 1010011 11 000010011 1011 0010 0010 010 0010 11 000000 000111 1001 1001 11 00110 010 0110 11 0111000 000001 01111 101011 010 1011 1010011 11 0111000 000011 000110 000110 11 00110 00010 1001 11 0111001 010 0110 1010101 11 00110 010 0010 11 00111101 010 1011 1001 1000 010 0110 11 000110 000011 011101 010 0010 11 0011111 000011 000001 01111 11 00110 010 0110 11 0111000 010 0000101 010 0010 11 1010101 000011 000000 000000 1000 11 00111000 000011 0010 11 000011 011101 010 0010 11 11 101000111 000111 000000 11 0111001 010 0110 1010101 010 11 00110 00010 1001 11 101011 1011 0110 11 010 0110 0010 1001 1000 11 011101 010 0110 010 1011 1000 010 0010 11 00111100 010 0011101 1011 010 000000 1000 11 1001 1011 000001 01111 11 101011 000011 01111 000110 11 010 1011 0010 11 010 0110 0010 1001 1000 010 1001 11 0111001 000011 0110 1000 11 0111001 010 0010 0010 11 0000101 000111 1000 010 11 000010011 010 00110 010 0010 11 1001 1011 010 11 011101 010 0000101 000110 010 1011 1000 010 0010 11 0011111 00010 0010 0010 11 1010000 000110 1011 010 1010011 1000 11 00110 1011 010 11 101000110 0110 011101 010 1011 1000 11 000000 000111 0010 1000 010 0110 11 1010000 000011 0110 1000 11 0111000 000011 11 000110 00010 1001 1001 1000 11 000111 0010 1001 11 10100010 010 1000 0011101 1000 11 000000 1011 1000 11 1010010 000110 010 1011 1010011 11 011101 010 1000 0110 00010 000001 01111 1000 010 0010 11 0111001 00010 1001 11 00110 000111 0110 000001 01111 11 00110 1011 010 11 1001 000001 01111 101011 00010 000001 01111 010 11 001110011 0110 00010 1010000 1000 11 010 0010 1000 1001 000010001 0110 1011 0010 0000101 1000 11 0011111 010 0010 11 1001 000001 01111 000110 010 000001 01111 1000 010 0010 11 00111101 00010 0010 0010 11 000000 000111 1001 1001 11 000000 00010 0010 11 00111000 010 0110 00010 000001 01111 1000 010 0010 11 0011111 010 0110 11 0010 1011 010 11 011101 010 00110 00010 000001 01111 1000 11 101011 00010 1001 11 010 0110 11 00111000 000011 000110 000110 011101 0110 1011 0010 0000101 1000 11 0011111 00010 1001 11 1011 1001 1000 1001 11 10100010 00010 11 101011 00010 1001 11 00110 010 0010 11 00111101 010 0010 1001 000001 01111 010 0010 11 0011101 1011 010 0110 010 1000 11 0000100001 0010 00110 11 00110 00010 0011101 000111 11 101011 00010 0110 00110 11 1011 01111 000000 11 00110 010 0110 11 001110010 010 0110 1001 1000 00010 0010 00110 11 0011111 00010 1001 1001 11 010 0110 11 1011 000000 11 1011 0010 0010 010 0110 0010 11 1010100 010 0110 0011101 010 0010 11 1001 000010001 0000100000 0110 010 1000 11 0111001 00010 1001 11 010 0110 11 010 0110 1001 000001 01111 00010 1010000 1010000 1000 11 000000 1011 1000 11 1001 010 1011 0010 010 0110 11 1010100 00010 0010 00110 11
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 0 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going right: wkHßFZAjf: 0.05
# DEBUG -   char: 0 | current node: wkHßFZAjf: 0.05     -- left: wkH: 0.02 | right: ßFZAjf: 0.03
# DEBUG -     going right: ßFZAjf: 0.03
# DEBUG -   char: 1 | current node: ßFZAjf: 0.03     -- left: ßF: 0.01 | right: ZAjf: 0.01
# DEBUG -     going left: ßF: 0.01
# DEBUG -   char: 0 | current node: ßF: 0.01     -- left: ß: 0.01 | right: F: 0.01
# DEBUG -     going right: F: 0.01
# DEBUG -     leaf reached: F
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 1 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going left: s: 0.06
# DEBUG -     leaf reached: s
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 1 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going left: ogRELpUü: 0.04
# DEBUG -   char: 0 | current node: ogRELpUü: 0.04     -- left: o: 0.02 | right: gRELpUü: 0.02
# DEBUG -     going right: gRELpUü: 0.02
# DEBUG -   char: 1 | current node: gRELpUü: 0.02     -- left: g: 0.01 | right: RELpUü: 0.01
# DEBUG -     going left: g: 0.01
# DEBUG -     leaf reached: g
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 0 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going right: cm: 0.05
# DEBUG -   char: 0 | current node: cm: 0.05     -- left: c: 0.02 | right: m: 0.02
# DEBUG -     going right: m: 0.02
# DEBUG -     leaf reached: m
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 1 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going left: ula: 0.08
# DEBUG -   char: 0 | current node: ula: 0.08     -- left: ul: 0.04 | right: a: 0.04
# DEBUG -     going right: a: 0.04
# DEBUG -     leaf reached: a
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 1 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going left: ula: 0.08
# DEBUG -   char: 1 | current node: ula: 0.08     -- left: ul: 0.04 | right: a: 0.04
# DEBUG -     going left: ul: 0.04
# DEBUG -   char: 1 | current node: ul: 0.04     -- left: u: 0.02 | right: l: 0.02
# DEBUG -     going left: u: 0.02
# DEBUG -     leaf reached: u
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 0 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going right: r: 0.07
# DEBUG -     leaf reached: r
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 1 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going left: i: 0.05
# DEBUG -     leaf reached: i
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 0 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going right: n: 0.08
# DEBUG -     leaf reached: n
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 1 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going left: DMGzKVvd: 0.08
# DEBUG -   char: 0 | current node: DMGzKVvd: 0.08     -- left: DMGzKVv: 0.04 | right: d: 0.04
# DEBUG -     going right: d: 0.04
# DEBUG -     leaf reached: d
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 0 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going right: r: 0.07
# DEBUG -     leaf reached: r
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 1 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going left: ogRELpUü: 0.04
# DEBUG -   char: 0 | current node: ogRELpUü: 0.04     -- left: o: 0.02 | right: gRELpUü: 0.02
# DEBUG -     going right: gRELpUü: 0.02
# DEBUG -   char: 0 | current node: gRELpUü: 0.02     -- left: g: 0.01 | right: RELpUü: 0.01
# DEBUG -     going right: RELpUü: 0.01
# DEBUG -   char: 1 | current node: RELpUü: 0.01     -- left: REL: 0.01 | right: pUü: 0.01
# DEBUG -     going left: REL: 0.01
# DEBUG -   char: 0 | current node: REL: 0.01     -- left: R: 0.00 | right: EL: 0.00
# DEBUG -     going right: EL: 0.00
# DEBUG -   char: 1 | current node: EL: 0.00     -- left: E: 0.00 | right: L: 0.00
# DEBUG -     going left: E: 0.00
# DEBUG -     leaf reached: E
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 0 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going right: r: 0.07
# DEBUG -     leaf reached: r
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 1 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going left: DMGzKVvd: 0.08
# DEBUG -   char: 0 | current node: DMGzKVvd: 0.08     -- left: DMGzKVv: 0.04 | right: d: 0.04
# DEBUG -     going right: d: 0.04
# DEBUG -     leaf reached: d
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 0 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going right: n: 0.08
# DEBUG -     leaf reached: n
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 1 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going left: hbWS: 0.06
# DEBUG -   char: 0 | current node: hbWS: 0.06     -- left: h: 0.03 | right: bWS: 0.03
# DEBUG -     going right: bWS: 0.03
# DEBUG -   char: 0 | current node: bWS: 0.03     -- left: b: 0.01 | right: WS: 0.02
# DEBUG -     going right: WS: 0.02
# DEBUG -   char: 0 | current node: WS: 0.02     -- left: W: 0.01 | right: S: 0.01
# DEBUG -     going right: S: 0.01
# DEBUG -     leaf reached: S
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 1 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going left: hbWS: 0.06
# DEBUG -   char: 1 | current node: hbWS: 0.06     -- left: h: 0.03 | right: bWS: 0.03
# DEBUG -     going left: h: 0.03
# DEBUG -     leaf reached: h
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 1 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going left: DMGzKVvd: 0.08
# DEBUG -   char: 0 | current node: DMGzKVvd: 0.08     -- left: DMGzKVv: 0.04 | right: d: 0.04
# DEBUG -     going right: d: 0.04
# DEBUG -     leaf reached: d
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 1 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going left: i: 0.05
# DEBUG -     leaf reached: i
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 0 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going right: wkHßFZAjf: 0.05
# DEBUG -   char: 0 | current node: wkHßFZAjf: 0.05     -- left: wkH: 0.02 | right: ßFZAjf: 0.03
# DEBUG -     going right: ßFZAjf: 0.03
# DEBUG -   char: 1 | current node: ßFZAjf: 0.03     -- left: ßF: 0.01 | right: ZAjf: 0.01
# DEBUG -     going left: ßF: 0.01
# DEBUG -   char: 0 | current node: ßF: 0.01     -- left: ß: 0.01 | right: F: 0.01
# DEBUG -     going right: F: 0.01
# DEBUG -     leaf reached: F
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 1 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going left: ogRELpUü: 0.04
# DEBUG -   char: 1 | current node: ogRELpUü: 0.04     -- left: o: 0.02 | right: gRELpUü: 0.02
# DEBUG -     going left: o: 0.02
# DEBUG -     leaf reached: o
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 0 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going right: r: 0.07
# DEBUG -     leaf reached: r
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 0 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going right: cm: 0.05
# DEBUG -   char: 0 | current node: cm: 0.05     -- left: c: 0.02 | right: m: 0.02
# DEBUG -     going right: m: 0.02
# DEBUG -     leaf reached: m
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 1 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going left: ula: 0.08
# DEBUG -   char: 0 | current node: ula: 0.08     -- left: ul: 0.04 | right: a: 0.04
# DEBUG -     going right: a: 0.04
# DEBUG -     leaf reached: a
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# ...
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 0 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going right: ogRELpUücm: 0.09
# DEBUG -   char: 0 | current node: ogRELpUücm: 0.09     -- left: ogRELpUü: 0.04 | right: cm: 0.05
# DEBUG -     going right: cm: 0.05
# DEBUG -   char: 0 | current node: cm: 0.05     -- left: c: 0.02 | right: m: 0.02
# DEBUG -     going right: m: 0.02
# DEBUG -     leaf reached: m
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 1 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going left: i: 0.05
# DEBUG -     leaf reached: i
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 0 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going right: t: 0.06
# DEBUG -     leaf reached: t
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 0 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going right: st: 0.12
# DEBUG -   char: 1 | current node: st: 0.12     -- left: s: 0.06 | right: t: 0.06
# DEBUG -     going left: s: 0.06
# DEBUG -     leaf reached: s
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 1 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going left: i: 0.05
# DEBUG -     leaf reached: i
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 0 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going right: n: 0.08
# DEBUG -     leaf reached: n
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 0 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going right: e: 0.14
# DEBUG -     leaf reached: e
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 1 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going left: hbWSre: 0.27
# DEBUG -   char: 1 | current node: hbWSre: 0.27     -- left: hbWSr: 0.13 | right: e: 0.14
# DEBUG -     going left: hbWSr: 0.13
# DEBUG -   char: 0 | current node: hbWSr: 0.13     -- left: hbWS: 0.06 | right: r: 0.07
# DEBUG -     going right: r: 0.07
# DEBUG -     leaf reached: r
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 0 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going right: iwkHßFZAjfst: 0.22
# DEBUG -   char: 1 | current node: iwkHßFZAjfst: 0.22     -- left: iwkHßFZAjf: 0.10 | right: st: 0.12
# DEBUG -     going left: iwkHßFZAjf: 0.10
# DEBUG -   char: 0 | current node: iwkHßFZAjf: 0.10     -- left: i: 0.05 | right: wkHßFZAjf: 0.05
# DEBUG -     going right: wkHßFZAjf: 0.05
# DEBUG -   char: 1 | current node: wkHßFZAjf: 0.05     -- left: wkH: 0.02 | right: ßFZAjf: 0.03
# DEBUG -     going left: wkH: 0.02
# DEBUG -   char: 0 | current node: wkH: 0.02     -- left: w: 0.01 | right: kH: 0.01
# DEBUG -     going right: kH: 0.01
# DEBUG -   char: 0 | current node: kH: 0.01     -- left: k: 0.01 | right: H: 0.01
# DEBUG -     going right: H: 0.01
# DEBUG -     leaf reached: H
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 0 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going right: ulaogRELpUücm: 0.18
# DEBUG -   char: 1 | current node: ulaogRELpUücm: 0.18     -- left: ula: 0.08 | right: ogRELpUücm: 0.09
# DEBUG -     going left: ula: 0.08
# DEBUG -   char: 0 | current node: ula: 0.08     -- left: ul: 0.04 | right: a: 0.04
# DEBUG -     going right: a: 0.04
# DEBUG -     leaf reached: a
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 0 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going right: n: 0.08
# DEBUG -     leaf reached: n
# DEBUG -   char: 0 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -   char: 0 | current node: hbWSreDMGzKVvdnulaogRELpUücm: 0.60     -- left: hbWSre: 0.27 | right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -     going right: DMGzKVvdnulaogRELpUücm: 0.33
# DEBUG -   char: 1 | current node: DMGzKVvdnulaogRELpUücm: 0.33     -- left: DMGzKVvdn: 0.16 | right: ulaogRELpUücm: 0.18
# DEBUG -     going left: DMGzKVvdn: 0.16
# DEBUG -   char: 1 | current node: DMGzKVvdn: 0.16     -- left: DMGzKVvd: 0.08 | right: n: 0.08
# DEBUG -     going left: DMGzKVvd: 0.08
# DEBUG -   char: 0 | current node: DMGzKVvd: 0.08     -- left: DMGzKVv: 0.04 | right: d: 0.04
# DEBUG -     going right: d: 0.04
# DEBUG -     leaf reached: d
# DEBUG -   char: 1 | current node:  iwkHßFZAjfsthbWSreDMGzKVvdnulaogRELpUücm: 1.00     -- left:  iwkHßFZAjfst: 0.40 | right: hbWSreDMGzKVvdnulaogRELpUücm: 0.60
# DEBUG -     going left:  iwkHßFZAjfst: 0.40
# DEBUG -   char: 1 | current node:  iwkHßFZAjfst: 0.40     -- left:  : 0.18 | right: iwkHßFZAjfst: 0.22
# DEBUG -     going left:  : 0.18
# DEBUG -     leaf reached:
# Original string : (645 bytes)  Fest gemauert in der Erden Steht die Form aus Lehm gebrannt Heute muss die Glocke werden Frisch Gesellen seid zur Hand Von der Stirne heiß Rinnen muss der Schweiß Soll das Werk den Meister loben Doch der Segen kommt von oben  Zum Werke das wir ernst bereiten Geziemt sich wohl ein ernstes Wort Wenn gute Reden sie begleiten Dann fließt die Arbeit munter fort So lasst uns jetzt mit Fleiß betrachten Was durch die schwache Kraft entspringt Den schlechten Mann muss man verachten Der nie bedacht was er vollbringt Das ists ja was den Menschen zieret Und dazu ward ihm der Verstand Dass er im innern Herzen spüret Was er erschafft mit seiner Hand
# Encoded string  : (348 bytes) 11 1010010 010 1001 1000 11 0000101 010 000000 00010 000111 010 0110 1000 11 1011 0010 11 00110 010 0110 11 0000100101 0110 00110 010 0010 11 0111000 1000 010 01111 1000 11 00110 1011 010 11 1010010 000011 0110 000000 11 00010 000111 1001 11 0000100100 010 01111 000000 11 0000101 010 011101 0110 00010 0010 0010 1000 11 1010100 010 000111 1000 010 11 000000 000111 1001 1001 11 00110 1011 010 11 00111100 000110 000011 000001 1010101 010 11 101011 010 0110 00110 010 0010 11 1010010 0110 1011 1001 000001 01111 11 00111100 010 1001 010 000110 000110 010 0010 11 1001 010 1011 00110 11 0011101 000111 0110 11 1010100 00010 0010 00110 11 001110010 000011 0010 11 00110 010 0110 11 0111000 1000 1011 0110 0010 010 11 01111 010 1011 1010011 11 000010011 1011 0010 0010 010 0010 11 000000 000111 1001 1001 11 00110 010 0110 11 0111000 000001 01111 101011 010 1011 1010011 11 0111000 000011 000110 000110 11 00110 00010 1001 11 0111001 010 0110 1010101 11 00110 010 0010 11 00111101 010 1011 1001 1000 010 0110 11 000110 000011 011101 010 0010 11 0011111 000011 000001 01111 11 00110 010 0110 11 0111000 010 0000101 010 0010 11 1010101 000011 000000 000000 1000 11 00111000 000011 0010 11 000011 011101 010 0010 11 11 101000111 000111 000000 11 0111001 010 0110 1010101 010 11 00110 00010 1001 11 101011 1011 0110 11 010 0110 0010 1001 1000 11 011101 010 0110 010 1011 1000 010 0010 11 00111100 010 0011101 1011 010 000000 1000 11 1001 1011 000001 01111 11 101011 000011 01111 000110 11 010 1011 0010 11 010 0110 0010 1001 1000 010 1001 11 0111001 000011 0110 1000 11 0111001 010 0010 0010 11 0000101 000111 1000 010 11 000010011 010 00110 010 0010 11 1001 1011 010 11 011101 010 0000101 000110 010 1011 1000 010 0010 11 0011111 00010 0010 0010 11 1010000 000110 1011 010 1010011 1000 11 00110 1011 010 11 101000110 0110 011101 010 1011 1000 11 000000 000111 0010 1000 010 0110 11 1010000 000011 0110 1000 11 0111000 000011 11 000110 00010 1001 1001 1000 11 000111 0010 1001 11 10100010 010 1000 0011101 1000 11 000000 1011 1000 11 1010010 000110 010 1011 1010011 11 011101 010 1000 0110 00010 000001 01111 1000 010 0010 11 0111001 00010 1001 11 00110 000111 0110 000001 01111 11 00110 1011 010 11 1001 000001 01111 101011 00010 000001 01111 010 11 001110011 0110 00010 1010000 1000 11 010 0010 1000 1001 000010001 0110 1011 0010 0000101 1000 11 0011111 010 0010 11 1001 000001 01111 000110 010 000001 01111 1000 010 0010 11 00111101 00010 0010 0010 11 000000 000111 1001 1001 11 000000 00010 0010 11 00111000 010 0110 00010 000001 01111 1000 010 0010 11 0011111 010 0110 11 0010 1011 010 11 011101 010 00110 00010 000001 01111 1000 11 101011 00010 1001 11 010 0110 11 00111000 000011 000110 000110 011101 0110 1011 0010 0000101 1000 11 0011111 00010 1001 11 1011 1001 1000 1001 11 10100010 00010 11 101011 00010 1001 11 00110 010 0010 11 00111101 010 0010 1001 000001 01111 010 0010 11 0011101 1011 010 0110 010 1000 11 0000100001 0010 00110 11 00110 00010 0011101 000111 11 101011 00010 0110 00110 11 1011 01111 000000 11 00110 010 0110 11 001110010 010 0110 1001 1000 00010 0010 00110 11 0011111 00010 1001 1001 11 010 0110 11 1011 000000 11 1011 0010 0010 010 0110 0010 11 1010100 010 0110 0011101 010 0010 11 1001 000010001 0000100000 0110 010 1000 11 0111001 00010 1001 11 010 0110 11 010 0110 1001 000001 01111 00010 1010000 1010000 1000 11 000000 1011 1000 11 1001 010 1011 0010 010 0110 11 1010100 00010 0010 00110 11
# Decoded string  :  Fest gemauert in der Erden Steht die Form aus Lehm gebrannt Heute muss die Glocke werden Frisch Gesellen seid zur Hand Von der Stirne heiß Rinnen muss der Schweiß Soll das Werk den Meister loben Doch der Segen kommt von oben  Zum Werke das wir ernst bereiten Geziemt sich wohl ein ernstes Wort Wenn gute Reden sie begleiten Dann fließt die Arbeit munter fort So lasst uns jetzt mit Fleiß betrachten Was durch die schwache Kraft entspringt Den schlechten Mann muss man verachten Der nie bedacht was er vollbringt Das ists ja was den Menschen zieret Und dazu ward ihm der Verstand Dass er im innern Herzen spüret Was er erschafft mit seiner Hand

# %% [markdown]
# Example from script:

# %%
string = "mamabanamaramarambakarambalama"
encoded_str = huffman.huffman.huffman_encode(string, absoluteValues=True)
decoded_str = huffman.huffman.huffman_decode(encoded_str)

print(f"Original string : {string}")
print(f"Encoded string  : {encoded_str}")
print(f"Decoded string  : {decoded_str}")
# Out:
# DEBUG - Char occurrence: [('n', 1), ('k', 1), ('l', 1), ('b', 3), ('r', 3), ('m', 7), ('a', 14)]
# DEBUG - relativeFreqDict: {'m': 7, 'a': 14, 'b': 3, 'n': 1, 'r': 3, 'k': 1, 'l': 1}
# DEBUG - heap: [n: 1.00, b: 3.00, k: 1.00, a: 14.00, r: 3.00, m: 7.00, l: 1.00]
# DEBUG -   merging nodes: n: 1.00, k: 1.00 -> nk: 2.00
# DEBUG -   merging nodes: l: 1.00, nk: 2.00 -> lnk: 3.00
# DEBUG -   merging nodes: b: 3.00, r: 3.00 -> br: 6.00
# DEBUG -   merging nodes: lnk: 3.00, br: 6.00 -> lnkbr: 9.00
# DEBUG -   merging nodes: m: 7.00, lnkbr: 9.00 -> mlnkbr: 16.00
# DEBUG -   merging nodes: a: 14.00, mlnkbr: 16.00 -> amlnkbr: 30.00
# DEBUG - merged_heapnode: amlnkbr: 30.00
# DEBUG - graph {
# 	amlnkbr [label="amlnkbr: 30.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	a [label="a: 14.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	amlnkbr -- a [label=1]
# 	mlnkbr [label="mlnkbr: 16.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	m [label="m: 7.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	mlnkbr -- m [label=1]
# 	lnkbr [label="lnkbr: 9.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	lnk [label="lnk: 3.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	l [label="l: 1.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	lnk -- l [label=1]
# 	nk [label="nk: 2.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	n [label="n: 1.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	nk -- n [label=1]
# 	k [label="k: 1.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	nk -- k [label=0]
# 	lnk -- nk [label=0]
# 	lnkbr -- lnk [label=1]
# 	br [label="br: 6.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	b [label="b: 3.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	br -- b [label=1]
# 	r [label="r: 3.00" color="#00998A" fillcolor="#BFE5E2" style=filled]
# 	br -- r [label=0]
# 	lnkbr -- br [label=0]
# 	mlnkbr -- lnkbr [label=0]
# 	amlnkbr -- mlnkbr [label=0]
# }
#
# DEBUG - codetable: {'a': '1', 'm': '01', 'l': '0011', 'n': '00101', 'k': '00100', 'b': '0001', 'r': '0000'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 string = "mamabanamaramarambakarambalama"
#       2 encoded_str = huffman.huffman.huffman_encode(string, absoluteValues=True)
# ----> 3 decoded_str = huffman.huffman.huffman_decode(encoded_str)
#       5 print(f"Original string : {string}")
#       6 print(f"Encoded string  : {encoded_str}")
#
# TypeError: huffman_decode() missing 1 required positional argument: 'heap_node'
